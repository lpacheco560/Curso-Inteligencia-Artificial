# %% [markdown]
# <a href="https://colab.research.google.com/github/lpacheco560/Curso-Inteligencia-Artificial/blob/main/EDA_Apuntes_de_Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA Analisis Exploratorios
# **Ejemplos**
#
# Importar librerias

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.4
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.2.10.0.33.26
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Feb 18 14:20 .
# drwxr-xr-x 1 root root 4096 Feb 19 21:25 ..
# drwxr-xr-x 4 root root 4096 Feb 18 14:19 .config
# drwxr-xr-x 1 root root 4096 Feb 18 14:20 sample_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.csv")
df.head()
# Out:
#   File "<ipython-input-12-f636b65a6bd0>", line 1
#     df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.csv")
#                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.csv

# %% [markdown]
# Con el sigiente veo los 10 primeros registros

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4a676c3d8c05> in <cell line: 0>()
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %% [markdown]
# Con este comando veo los ultimos datos

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4add252522c8> in <cell line: 0>()
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
df.local=pd.read_csv("vivienda_clasif.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-638cb66a13e0> in <cell line: 0>()
# ----> 1 df.local=pd.read_csv("vivienda_clasif.csv")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-00cf07b74dcd> in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df_github=pd.read_csv("https://raw.githubusercontent.com/lpacheco560/Curso-Inteligencia-Artificial/refs/heads/main/preprocesamiento/vivienda_clasif.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-89071052b9da> in <cell line: 0>()
#       1 df_github=pd.read_csv("https://raw.githubusercontent.com/lpacheco560/Curso-Inteligencia-Artificial/refs/heads/main/preprocesamiento/vivienda_clasif.csv")
# ----> 2 df
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-633337079cd0> in <cell line: 0>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-00cf07b74dcd> in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import numpy as np

# Set random seed
np.random.seed(42)

# Create 'saldo' array with synthetic bank balance data
saldo = np.random.randint(1000, 10000, size=20)  # Random balances between 1000 and 10000

# Create 'antiguedad' array for bank account age
antiguedad = np.arange(0, 10, 0.5)  # Values from 0 to 10 with a step of 0.5

# Create 'ubicacion' matrix with latitude and longitude near Bucaramanga
latitud = 7.12 + np.random.rand(20) * 0.1  # Vary latitude around 7.12
longitud = -73.12 + np.random.rand(20) * 0.1  # Vary longitude around -73.12
ubicacion = np.column_stack((latitud, longitud))

# Combine using column_stack
datos_combinados = np.column_stack((saldo, antiguedad, ubicacion))

print(datos_combinados)
# Out:
# [[ 8.27000000e+03  0.00000000e+00  7.17247564e+00 -7.31102328e+01]
#  [ 1.86000000e+03  5.00000000e-01  7.16319450e+00 -7.30515767e+01]
#  [ 6.39000000e+03  1.00000000e+00  7.14912291e+00 -7.30759848e+01]
#  [ 6.19100000e+03  1.50000000e+00  7.18118529e+00 -7.31077962e+01]
#  [ 6.73400000e+03  2.00000000e+00  7.13394939e+00 -7.30704823e+01]
#  [ 7.26500000e+03  2.50000000e+00  7.14921446e+00 -7.31165611e+01]
#  [ 1.46600000e+03  3.00000000e+00  7.15663618e+00 -7.30290680e+01]
#  [ 5.42600000e+03  3.50000000e+00  7.16560700e+00 -7.30941220e+01]
#  [ 6.57800000e+03  4.00000000e+00  7.19851760e+00 -7.30537478e+01]
#  [ 9.32200000e+03  4.50000000e+00  7.13996738e+00 -7.30888289e+01]
#  [ 2.68500000e+03  5.00000000e+00  7.17142344e+00 -7.30679932e+01]
#  [ 1.76900000e+03  5.50000000e+00  7.17924146e+00 -7.30653290e+01]
#  [ 7.94900000e+03  6.00000000e+00  7.12464504e+00 -7.31015146e+01]
#  [ 3.43300000e+03  6.50000000e+00  7.18075449e+00 -7.30230415e+01]
# ...

# %%
datos_combinados.shape
# Out:
# (20, 4)

# %%
print("media",np.mean(datos_combinados[0]),"\n","max",np.max(datos_combinados[0]),"\n","min",np.min(datos_combinados[0]))
# Out:
# media 2051.0155607136408
#  max 8270.0
#  min -73.11023278859936

# %%
datos_combinados[:,:] # exactamente igual a datos_combinados
# Out:
# array([[ 8.27000000e+03,  0.00000000e+00,  7.17247564e+00,
#         -7.31102328e+01],
#        [ 1.86000000e+03,  5.00000000e-01,  7.16319450e+00,
#         -7.30515767e+01],
#        [ 6.39000000e+03,  1.00000000e+00,  7.14912291e+00,
#         -7.30759848e+01],
#        [ 6.19100000e+03,  1.50000000e+00,  7.18118529e+00,
#         -7.31077962e+01],
#        [ 6.73400000e+03,  2.00000000e+00,  7.13394939e+00,
#         -7.30704823e+01],
#        [ 7.26500000e+03,  2.50000000e+00,  7.14921446e+00,
#         -7.31165611e+01],
#        [ 1.46600000e+03,  3.00000000e+00,  7.15663618e+00,
#         -7.30290680e+01],
#        [ 5.42600000e+03,  3.50000000e+00,  7.16560700e+00,
#         -7.30941220e+01],
#        [ 6.57800000e+03,  4.00000000e+00,  7.19851760e+00,
#         -7.30537478e+01],
#        [ 9.32200000e+03,  4.50000000e+00,  7.13996738e+00,
#         -7.30888289e+01],
#        [ 2.68500000e+03,  5.00000000e+00,  7.17142344e+00,
#         -7.30679932e+01],
# ...

# %% [markdown]
# Como mostrar datos con ubicación negativa, la matriz es de 20 líneas, las filas son la X y las columnas Y

# %%
datos_combinados[-5:-2,1:3]
# Out:
# array([[7.5       , 7.12650516],
#        [8.        , 7.21488855],
#        [8.5       , 7.2165632 ]])

# %%
# prompt: creame una lista de 20 nombres colombianos en un arreglo de numpy que se llaman nombre

import numpy as np

nombres = np.array(['Juan', 'Ana', 'Carlos', 'Sofia', 'David', 'Maria', 'Jose', 'Laura', 'Miguel', 'Valentina',
                   'Sebastian', 'Camila', 'Alejandro', 'Isabella', 'Daniel', 'Gabriela', 'Nicolas', 'Sofia', 'Mateo', 'Andrea'])

# %%
nombres
# Out:
# array(['Juan', 'Ana', 'Carlos', 'Sofia', 'David', 'Maria', 'Jose',
#        'Laura', 'Miguel', 'Valentina', 'Sebastian', 'Camila', 'Alejandro',
#        'Isabella', 'Daniel', 'Gabriela', 'Nicolas', 'Sofia', 'Mateo',
#        'Andrea'], dtype='<U9')

# %%
n

# %%
# prompt: crea un dataframe que una nombre, saldos, atiguedad, latitud, longitud

import pandas as pd
import numpy as np

# Assuming 'nombres', 'saldo', 'antiguedad', 'latitud', and 'longitud' are defined as in the previous code

# Create a DataFrame
data = {'nombre': nombres,
        'saldo': saldo,
        'antiguedad': antiguedad,
        'latitud': latitud,
        'longitud': longitud}
df = pd.DataFrame(data)

df
# Out:
#        nombre  saldo  antiguedad   latitud   longitud
# 0        Juan   8270         0.0  7.172476 -73.110233
# 1         Ana   1860         0.5  7.163195 -73.051577
# 2      Carlos   6390         1.0  7.149123 -73.075985
# 3       Sofia   6191         1.5  7.181185 -73.107796
# 4       David   6734         2.0  7.133949 -73.070482
# 5       Maria   7265         2.5  7.149214 -73.116561
# 6        Jose   1466         3.0  7.156636 -73.029068
# 7       Laura   5426         3.5  7.165607 -73.094122
# 8      Miguel   6578         4.0  7.198518 -73.053748
# 9   Valentina   9322         4.5  7.139967 -73.088829
# 10  Sebastian   2685         5.0  7.171423 -73.067993
# 11     Camila   1769         5.5  7.179241 -73.065329
# 12  Alejandro   7949         6.0  7.124645 -73.101515
# 13   Isabella   3433         6.5  7.180754 -73.023042
# 14     Daniel   6311         7.0  7.137052 -73.042487
# 15   Gabriela   6051         7.5  7.126505 -73.026050
# ...

# %%
df.to_excel("datos.xlsx")
